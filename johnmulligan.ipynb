# %% [markdown]
# # Background
#
# Last week and early this week, we worked on:
#
# * [Writing documentation in Markdown](https://github.com/JohnMulligan/road_documentation_exercise/)
# * [Exploring different data presentations](https://github.com/JohnMulligan/road_requests_exercise/tree/main) from the US Library of Congress
#   * An API view (e.g., of [10th-16th Century Liturgical Chants](https://www.loc.gov/collections/tenth-to-sixteenth-century-liturgical-chants/?fo=json&at=results))
#   * A webpage view ([same example](https://www.loc.gov/collections/tenth-to-sixteenth-century-liturgical-chants/))
#
# ## Today
#
#  Using [Google Colab](https://colab.google/), we will work on combining our documentation and API exercises by using notebooks, which allow markdown to be folded together with runnable code and its outputs.
#
#  Your assignment is to
#
# * continue exploring the LOC resources programmatically
#   * you can continue your previous work
#   * or you can start looking at a new collection
#   * or a new presentation of the data
# * and writing up what you find
# * but this time, doing it in a notebook so that you can combine
#   * the code you ran
#   * the results of that code
#   * your markdown-formatted writeup of
#     * what you found and
#     * what your code does
#
# ### Resources
#
# I suggest using as a guide one of the below writeups provided by the Library of Congress -- which, helpfully, are written up in notebooks!
#
# 1. [The JSON format API](https://github.com/LibraryOfCongress/data-exploration/blob/master/loc.gov%20JSON%20API/LOC.gov%20JSON%20API.ipynb) we previously used
# 1. [The IIIF API](https://github.com/LibraryOfCongress/data-exploration/blob/master/loc.gov%20IIIF%20API/IIIF.ipynb)
#
# However, feel free to explore their full collection: https://github.com/LibraryOfCongress/data-exploration/
#
# ### Submitting your work
#
# When you're ready to submit your work, you can:
#
# 1. Fork my repository
# 1. Export your notebook as an ```.ipynb``` file
# 1. Upload it to your fork of the repository, following the ```{MyUserName}.ipynb``` format (see below screenshot)
# 1. Open a PR to my fork's main branch
#
#
# ![export_notebook.jpg](data:image/jpeg;base64,...)
